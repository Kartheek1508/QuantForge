# %%
from ipynb.fs.defs.predict import predict_signal
from ipynb.fs.defs.data import reinforcement_data
def portfolio_recommendations(portfolio, cash):

    recommendations = []

    portfolio_value = (cash+ sum(stock["position_value"]for stock in portfolio))

    for stock in portfolio:

        ticker = stock["ticker"]

        current_price = float(
            reinforcement_data(ticker,"2023-01-01","2025-12-31").iloc[-1])

        position_fraction = (stock["position_value"]/ portfolio_value)

        unrealized_pnl = (current_price- stock["avg_buy_price"]) / stock["avg_buy_price"]

        signal = predict_signal(
            ticker=ticker,
            position_fraction=position_fraction,
            unrealized_pnl=unrealized_pnl
        )

        recommendations.append({
            "ticker": ticker,
            "action": signal["action"],
            "price": current_price,
            "position_value": stock["position_value"],
            "portfolio_weight": round(position_fraction * 100, 2),
            "unrealized_pnl": round(unrealized_pnl * 100, 2)
        })

    return recommendations

# %%
#example
portfolio = [
    {
        "ticker": "AAPL",
        "position_value": 3000,
        "avg_buy_price": 200
    },
    {
        "ticker": "MSFT",
        "position_value": 2000,
        "avg_buy_price": 400
    }
]

cash = 5000

portfolio_recommendations(
    portfolio,
    cash
)
# Out:
# [*********************100%***********************]  1 of 1 completed
# /var/folders/m8/v3941kwj11q83c2qdmmd4d8r0000gn/T/ipykernel_32430/2626015417.py:13: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   current_price = float(
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# /var/folders/m8/v3941kwj11q83c2qdmmd4d8r0000gn/T/ipykernel_32430/2626015417.py:13: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   current_price = float(
# [*********************100%***********************]  1 of 1 completed
# Model loaded from models/dqn_trader.pt
# Q Values: tensor([1478808.7500, 1476076.1250, 1479822.3750, 1469775.1250, 1446349.6250])
# Valid Actions: [0, 1, 2, 3, 4]
# Model loaded from models/dqn_trader.pt
# Q Values: tensor([1433659.0000, 1431010.0000, 1434640.8750, 1424900.3750, 1402193.2500])
# Valid Actions: [0, 1, 2, 3, 4]
# [{'ticker': 'AAPL',
#   'action': 'BUY_100',
#   'price': 272.57354736328125,
#   'position_value': 3000,
#   'portfolio_weight': 30.0,
#   'unrealized_pnl': 36.29},
#  {'ticker': 'MSFT',
#   'action': 'BUY_100',
#   'price': 485.3187561035156,
#   'position_value': 2000,
#   'portfolio_weight': 20.0,
#   'unrealized_pnl': 21.33}]
